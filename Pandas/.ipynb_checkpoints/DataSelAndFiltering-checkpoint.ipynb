# %%
import pandas as pd

df=pd.read_csv("sample_students.csv")
df
# Out:
#      ID        Name  Age       City  Score Passed
# 0     1    Student1   20     Mumbai     37     No
# 1     2    Student2   21      Delhi     44     No
# 2     3    Student3   22  Bangalore     51    Yes
# 3     4    Student4   23  Hyderabad     58    Yes
# 4     5    Student5   19    Chennai     65    Yes
# ..  ...         ...  ...        ...    ...    ...
# 95   96   Student96   20       Pune     72    Yes
# 96   97   Student97   21     Mumbai     79    Yes
# 97   98   Student98   22      Delhi     86    Yes
# 98   99   Student99   23  Bangalore     93    Yes
# 99  100  Student100   19  Hyderabad     30     No
#
# [100 rows x 6 columns]

# %%
df["Name"]
# Out:
# 0       Student1
# 1       Student2
# 2       Student3
# 3       Student4
# 4       Student5
#          ...
# 95     Student96
# 96     Student97
# 97     Student98
# 98     Student99
# 99    Student100
# Name: Name, Length: 100, dtype: object

# %%
df[["Name","Score"]]
# Out:
#           Name  Score
# 0     Student1     37
# 1     Student2     44
# 2     Student3     51
# 3     Student4     58
# 4     Student5     65
# ..         ...    ...
# 95   Student96     72
# 96   Student97     79
# 97   Student98     86
# 98   Student99     93
# 99  Student100     30
#
# [100 rows x 2 columns]

# %%
df.loc[0]
# Out:
# ID               1
# Name      Student1
# Age             20
# City        Mumbai
# Score           37
# Passed          No
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# ID               1
# Name      Student1
# Age             20
# City        Mumbai
# Score           37
# Passed          No
# Name: 0, dtype: object

# %%
df.loc[0,"Name"]
# Out:
# 'Student1'

# %%
df.iloc[0,1]
# Out:
# 'Student1'

# %%
df.loc[0:2,["Name","Age"]]
# Out:
#        Name  Age
# 0  Student1   20
# 1  Student2   21
# 2  Student3   22

# %%
df.iloc[0:2,0:2]
# Out:
#    ID      Name
# 0   1  Student1
# 1   2  Student2

# %%
df.at[0,"Name"]
# Out:
# 'Student1'

# %%
df.iat[0,1]
# Out:
# 'Student1'

# %%
#Filtering
df[df['Age']>21]
# Out:
#     ID       Name  Age       City  Score Passed
# 2    3   Student3   22  Bangalore     51    Yes
# 3    4   Student4   23  Hyderabad     58    Yes
# 7    8   Student8   22      Delhi     86    Yes
# 8    9   Student9   23  Bangalore     93    Yes
# 12  13  Student13   22     Mumbai     51    Yes
# 13  14  Student14   23      Delhi     58    Yes
# 17  18  Student18   22       Pune     86    Yes
# 18  19  Student19   23     Mumbai     93    Yes
# 22  23  Student23   22    Chennai     51    Yes
# 23  24  Student24   23       Pune     58    Yes
# 27  28  Student28   22  Hyderabad     86    Yes
# 28  29  Student29   23    Chennai     93    Yes
# 32  33  Student33   22  Bangalore     51    Yes
# 33  34  Student34   23  Hyderabad     58    Yes
# 37  38  Student38   22      Delhi     86    Yes
# 38  39  Student39   23  Bangalore     93    Yes
# 42  43  Student43   22     Mumbai     51    Yes
# 43  44  Student44   23      Delhi     58    Yes
# 47  48  Student48   22       Pune     86    Yes
# ...

# %%
df[(df["Name"] == "Bob") | (df["Age"] < 30)]
# Out:
#      ID        Name  Age       City  Score Passed
# 0     1    Student1   20     Mumbai     37     No
# 1     2    Student2   21      Delhi     44     No
# 2     3    Student3   22  Bangalore     51    Yes
# 3     4    Student4   23  Hyderabad     58    Yes
# 4     5    Student5   19    Chennai     65    Yes
# ..  ...         ...  ...        ...    ...    ...
# 95   96   Student96   20       Pune     72    Yes
# 96   97   Student97   21     Mumbai     79    Yes
# 97   98   Student98   22      Delhi     86    Yes
# 98   99   Student99   23  Bangalore     93    Yes
# 99  100  Student100   19  Hyderabad     30     No
#
# [100 rows x 6 columns]

# %%
df[(df["Age"] > 20) & (df["City"] == "Delhi")]
# Out:
#     ID       Name  Age   City  Score Passed
# 1    2   Student2   21  Delhi     44     No
# 7    8   Student8   22  Delhi     86    Yes
# 13  14  Student14   23  Delhi     58    Yes
# 31  32  Student32   21  Delhi     44     No
# 37  38  Student38   22  Delhi     86    Yes
# 43  44  Student44   23  Delhi     58    Yes
# 61  62  Student62   21  Delhi     44     No
# 67  68  Student68   22  Delhi     86    Yes
# 73  74  Student74   23  Delhi     58    Yes
# 91  92  Student92   21  Delhi     44     No
# 97  98  Student98   22  Delhi     86    Yes
