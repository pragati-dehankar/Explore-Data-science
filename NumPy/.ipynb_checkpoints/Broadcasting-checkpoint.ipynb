# %%
import numpy as np

arr=np.array([1,2,3,4,5])
res=arr**2
print(res)
# Out:
# [ 1  4  9 16 25]

# %%
ans=arr+12
print(ans)
# Out:
# [13 14 15 16 17]

# %%
arr1=np.array([23,34,45])
arr2=np.array([12,32,22])
r=arr1+arr2
print(r)
# Out:
# [35 66 67]

# %%
a1=np.array([12,13,14])
a2=np.array([[15,16,17],[21,31,41]])
a=a1+a2
print(a)
# Out:
# [[27 29 31]
#  [33 44 55]]
