# %%
import numpy as np

arr=np.array([12,32,34,45,56,67,90])
np.mean(arr)
# Out:
# np.float64(48.0)

# %%
np.std(arr)
# Out:
# np.float64(23.742668041192964)

# %%
np.var(arr)
# Out:
# np.float64(563.7142857142857)

# %%
np.min(arr)
# Out:
# np.int64(12)

# %%
np.max(arr)
# Out:
# np.int64(90)

# %%
np.sum(arr)
# Out:
# np.int64(336)

# %%
np.prod(arr)
# Out:
# np.int64(198393753600)

# %%
np.median(arr)
# Out:
# np.float64(45.0)

# %%
np.percentile(arr,20)
# Out:
# np.float64(32.4)

# %%
np.argmin(arr)
# Out:
# np.int64(0)

# %%
np.argmax(arr)
# Out:
# np.int64(6)

# %%
np.corrcoef(arr)
# Out:
# np.float64(1.0)

# %%
np.unique(arr)
# Out:
# array([12, 32, 34, 45, 56, 67, 90])

# %%
np.diff(arr)
# Out:
# array([20,  2, 11, 11, 11, 23])

# %%
np.cumsum(arr)
# Out:
# array([ 12,  44,  78, 123, 179, 246, 336])

# %%
np.log(arr)
# Out:
# array([2.48490665, 3.4657359 , 3.52636052, 3.80666249, 4.02535169,
#        4.20469262, 4.49980967])

# %%
np.exp(arr)
# Out:
# array([1.62754791e+05, 7.89629602e+13, 5.83461743e+14, 3.49342711e+19,
#        2.09165950e+24, 1.25236317e+29, 1.22040329e+39])
