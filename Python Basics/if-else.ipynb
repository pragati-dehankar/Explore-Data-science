# %%
num=int(input("enter a number"))
if(num%2==0):
    print("even")
else:
    print("odd")
# Out:
# enter a number -6
# even

# %%
if(num>0):
    print("Positive")
elif num<0:
    print("Negative")
else:
    print("Zero")
# Out:
# Negative

# %%
a=int(input("Enter a num"))
b=int(input("Enter b  num"))
if(a>b):
    print("a is greater")
else:
    print("b is greater")
# Out:
# Enter a num 34
# Enter a num 32
# a is greater
