# %%
a={1,"apple",2,"Banna",3,"Angur"}
a.add(4)
a
# Out:
# {1, 2, 3, 4, 'Angur', 'Banna', 'apple'}

# %%
a.update([5,"langur",6])
a
# Out:
# {1, 2, 3, 4, 5, 6, 'Angur', 'Banna', 'apple', 'langur'}

# %%
a.remove(1)
a
# Out:
# {2, 3, 4, 5, 6, 'Angur', 'Banna', 'apple', 'langur'}

# %%
a.discard(6)
a
# Out:
# {2, 3, 4, 5, 'Angur', 'Banna', 'apple', 'langur'}

# %%
a.pop()
# Out:
# 'apple'

# %%
a
# Out:
# {2, 3, 4, 5, 'Angur', 'Banna', 'langur'}

# %%
new_set=a.copy()
new_set
# Out:
# {2, 3, 4, 5, 'Angur', 'Banna', 'langur'}

# %%
a.clear()
a
# Out:
# set()

# %%
set1={1,"apple",2,"banana",3,'papaya'}
set2={3,"chapati",4,"Broom",5,"Bike","papaya"}
set2.union(set1)
# Out:
# {1, 2, 3, 4, 5, 'Bike', 'Broom', 'apple', 'banana', 'chapati', 'papaya'}

# %%
set1.intersection(set2)
# Out:
# {3, 'papaya'}

# %%
set1.symmetric_difference(set2)
# Out:
# {1, 2, 4, 5, 'Bike', 'Broom', 'apple', 'banana', 'chapati'}

# %%
set1.issubset(set2)
# Out:
# False

# %%
set1.issuperset(set2)
# Out:
# False

# %%
set2.issuperset(set1)
# Out:
# False
