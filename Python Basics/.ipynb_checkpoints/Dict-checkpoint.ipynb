# %%
std={"Name":"prachi","Age":21}
std.keys()
# Out:
# dict_keys(['Name', 'Age'])

# %%
std.values()
# Out:
# dict_values(['prachi', 21])

# %%
std.items()
# Out:
# dict_items([('Name', 'prachi'), ('Age', 21)])

# %%
std.get("age",0)
# Out:
# 0

# %%
std.get("Age",0)
# Out:
# 21

# %%
std.pop("Age")
# Out:
# 21

# %%
std.popitem()
# Out:
# ('Name', 'prachi')

# %%
std
# Out:
# {}
