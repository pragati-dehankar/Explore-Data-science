# %%
a=5

# %%
b=90

# %%
a+b
# Out:
# 95

# %%
n="P"

# %%
n
# Out:
# 'P'

# %%
type(a)
# Out:
# int

# %%
print(type(n))
# Out:
# <class 'str'>

# %%
a="124"
b="9087"
a+b
# Out:
# '1249087'

# %%
int(a)+int(b)
# Out:
# 9211

# %%
print("Hey")
# Out:
# Hey

# %%
45*9
# Out:
# 405
