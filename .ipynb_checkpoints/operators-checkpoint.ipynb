# %%
a=34
b=37
a+b
# Out:
# 71

# %%
a-b
# Out:
# -3

# %%
a*b
# Out:
# 1258

# %%
b/a
# Out:
# 1.088235294117647

# %%
a//b
# Out:
# 0

# %%
a%b
# Out:
# 34

# %%
a**4
# Out:
# 1336336

# %%
a**b
# Out:
# 462082935536608083712617840903502214718703588813721042944

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a>=b
# Out:
# False

# %%
a<b
# Out:
# True

# %%
a<=b
# Out:
# True

# %%
a and b
# Out:
# 37

# %%
a or b
# Out:
# 34

# %%
not a
# Out:
# False

# %%
a & b
# Out:
# 32

# %%
li=["apple","banana","tomato"]
'apple' in li
# Out:
# True

# %%
'banana' not in li
# Out:
# False

# %%
t=67
m=90

t is m
# Out:
# False

# %%
m is not t
# Out:
# True
