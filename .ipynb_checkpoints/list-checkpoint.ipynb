# %%
li=[12,34,56.7,43,32,19]
li.append(57)
print(li)
# Out:
# [12, 34, 56.7, 43, 32, 19, 57]

# %%
li.extend([45,67,87])
li
# Out:
# [12, 34, 56.7, 43, 32, 19, 57, 45, 67, 87]

# %%
li.insert(1,23)
li
# Out:
# [12, 23, 34, 56.7, 43, 32, 19, 57, 45, 67, 87]

# %%
li.remove(87)
li
# Out:
# [12, 23, 34, 56.7, 43, 32, 19, 57, 45, 67]

# %%
li.pop(3)
# Out:
# 43

# %%
li.index(43)
# Out:
# 3

# %%
li.count(12)
# Out:
# 1

# %%
li.sort()
li
# Out:
# [12, 19, 23, 32, 34, 45, 57, 67]

# %%
li.reverse()

# %%
li
# Out:
# [67, 57, 45, 34, 32, 23, 19, 12]

# %%
li.clear()

# %%
li
# Out:
# []
