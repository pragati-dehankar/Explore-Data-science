# %%
str="Prachi"
str.upper()
# Out:
# 'PRACHI'

# %%
str.lower()
# Out:
# 'prachi'

# %%
str.title()
# Out:
# 'Prachi'

# %%
str.title()
# Out:
# 'Prachi'

# %%
h="    hihihi          "
h.strip()
# Out:
# 'hihihi'

# %%
h.replace(" ","x")
# Out:
# 'xxxxhihihixxxxxxxxxx'

# %%
"p,r,a,c,h,i".split()
# Out:
# ['p,r,a,c,h,i']

# %%
".".join(["a","b","c"])
# Out:
# 'a.b.c'

# %%
a="Great,Wow,Nice"
a.split(",")
# Out:
# ['Great', 'Wow', 'Nice']

# %%
li=["a","b",'c']
a.join(li)
# Out:
# 'aGreat,Wow,NicebGreat,Wow,Nicec'

# %%
a.find('Wow')
# Out:
# 6

# %%
a.count('e')
# Out:
# 2

# %%
a.startswith('')
# Out:
# True

# %%
a.endswith('c')
# Out:
# False

# %%
a.isdigit()
# Out:
# False

# %%
a.isalpha()
# Out:
# False

# %%
a.isalnum()
# Out:
# False

# %%
#String formatting
Name="Pragati"
age=21
f"Hello , This is {Name} and I'm {age} years old."
# Out:
# "Hello , This is Pragati and I'm 21 years old."
